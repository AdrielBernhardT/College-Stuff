# %%
from Bio.Seq import Seq
from Bio import SeqIO

# %%
fasta =SeqIO.parse("sequence.fasta", "fasta")

genbank =SeqIO.parse("sequence.gb", "genbank")

# %%
print(fasta)

for record in fasta:
    print(record.id)
    print(record.seq)
    print(record.description)
